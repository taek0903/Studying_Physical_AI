# %%
import rclpy
from rclpy.node import Node
from rclpy.action import ActionClient
from turtlesim.action import RotateAbsolute

# %%
class TurtleRotateClient(Node):
    
    def __init__(self):
        super().__init__('turtle_rotate_client')
        self.client = ActionClient(self, RotateAbsolute, '/turtle1/rotate_absolute')
        self.get_logger().info('Action client started')

    def send_goal(self, theta):
        goal = RotateAbsolute.Goal()
        goal.theta = theta

        if not self.client.wait_for_server(timeout_sec=10.0):
            self.get_logger().info('Action server not available.')
            return

        goal_future = self.client.send_goal_async(goal, feedback_callback=self.feedback_callback)
        goal_future.add_done_callback(self.goal_response_callback)

    def goal_response_callback(self, future):
        handle = future.result()

        if not handle.accepted:
            self.get_logger().info('Goal rejected.')
            return
        
        self.get_logger().info('Goal accepted.')
        result_future = handle.get_result_async()
        result_future.add_done_callback(self.result_callback)

    def feedback_callback(self, feedback_msg):
        feedback = feedback_msg.feedback
        self.get_logger().info(f'Received feedback: remaining = {feedback.remaining:.2f}')

    def result_callback(self, future):
        result = future.result().result
        self.get_logger().info(f'Received result: delta = {result.delta:.2f}')
        self.destroy_node()   
        rclpy.shutdown()

# %%
rclpy.init()

client = TurtleRotateClient()
# Out:
# [INFO] [1773901529.069298027] [turtle_rotate_client]: Action client started

# %%
client.send_goal(3.14)

# %%
client.send_goal(0.0)

# %%
rclpy.spin(client)

# %%
client.destroy_node()

# %%
rclpy.shutdown()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rclpy.shutdown()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py:130, in shutdown(context, uninstall_handlers)
#     117 def shutdown(*, context: Context = None, uninstall_handlers: Optional[bool] = None) -> None:
#     118     """
#     119     Shutdown a previously initialized context.
#     120
#    (...)
#     128         If not, signal handlers won't be uninstalled.
#     129     """
# --> 130     _shutdown(context=context)
#     131     if (
#     132         uninstall_handlers or (
#     133             uninstall_handlers is None and (
#     134                 context is None or context is get_default_context()))
#     135     ):
#     136         uninstall_signal_handlers()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/utilities.py:58, in shutdown(context)
#      56 if context is None:
#      57     context = get_default_context(shutting_down=True)
# ---> 58 return context.shutdown()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/context.py:100, in Context.shutdown(self)
#      98 """Shutdown this context."""
#      99 if self.__context is None:
# --> 100     raise RuntimeError('Context must be initialized before it can be shutdown')
#     101 with self.__context, self._lock:
#     102     self.__context.shutdown()
#
# RuntimeError: Context must be initialized before it can be shutdown
