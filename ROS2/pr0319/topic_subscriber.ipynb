# %%
import rclpy as rp
from turtlesim.msg import Pose

# %%
rp.init()
test_node = rp.create_node('sub_test')

# %%
def callback(data):
    print("--->")
    print("/turtle1/pose : ", data)
    print("X : ", data.x)
    print("Y : ", data.y)
    print("Theta : ", data.theta)

# %%
test_node.create_subscription(Pose, 'turtle1/pose', callback, 10)

# %%
rp.spin_once(test_node)
# Out:
# --->
# /turtle1/pose :  turtlesim.msg.Pose(x=7.568554401397705, y=8.444657325744629, theta=2.3359999656677246, linear_velocity=0.0, angular_velocity=0.0)
# X :  7.568554401397705
# Y :  8.444657325744629
# Theta :  2.3359999656677246
